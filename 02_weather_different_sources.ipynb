# %% [markdown]
# # 02 Handle different source data on the example of weather data
#
# I like to practise analysing different source data in different file formats, determine differences and join them together to a single output. Weather data is free and available in many formats (json, csv, xml etc.) so that I consider this being a nice example.
#
# **Learnings:**
# * requesting APIs (JSON response); if neccessary, use `stream=True`and `iter_content()`
# * pretty print json with `json.dumps()`
# * `pd.json_normalize()` to create DataFrame from json
# * DataFrame processing with `df[ df[condition_col] == condition_value, change_col] = value`
# * `merge()` `DataFrameGoupBy` back into original DataFrame
# * Simulate SUM(col) OVER(ORDER BY group_col1 PARTITION BY group_col2) with pandas
#
# ## 1 Load source data
#
# When the data in `requests.request("GET", url, params=querystring)` is too large for memory, it should be done with an additional `stream` argument within in the function call:
# ```py
# with requests.get(url, stream=True) as r:
#     r.raise_for_status() #shows html error if arises
#     for chunk in r.iter_content(chunk_size=8192): #in bytes (1MB = million iters)
#         #or r.iter_lines() #parses line by line
#         tmp = pd.json_normalize(chunk, *kwargs) #process that json chunk
#         df.append(tmp)
# ```
#
# ## 1.1 Open Weather Map

# %%
import requests
import os

url = "https://api.openweathermap.org/data/2.5/onecall"
#Leipzig in [51.3396, 12.3713]
querystring = {"lat":"51.3396", "lon": "12.3713", "exclude": "current,minutely", "units":"metric", "appid":OWM_KEY} #parameters

headers = {} #TODO what are headers for?

# %%
response_owm = requests.request("GET", url, params=querystring)
print(response_owm.text)
# Out:
# {"lat":51.3396,"lon":12.3713,"timezone":"Europe/Berlin","timezone_offset":7200,"hourly":[{"dt":1626184800,"temp":29.47,"feels_like":29.42,"pressure":1006,"humidity":43,"dew_point":15.59,"uvi":4.16,"clouds":20,"visibility":10000,"wind_speed":4.18,"wind_deg":77,"wind_gust":5.65,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}],"pop":0},{"dt":1626188400,"temp":29.19,"feels_like":29.43,"pressure":1006,"humidity":46,"dew_point":16.39,"uvi":2.71,"clouds":28,"visibility":10000,"wind_speed":4.42,"wind_deg":63,"wind_gust":5.61,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}],"pop":0},{"dt":1626192000,"temp":28.53,"feels_like":29.07,"pressure":1006,"humidity":50,"dew_point":17.1,"uvi":1.25,"clouds":40,"visibility":10000,"wind_speed":4.31,"wind_deg":57,"wind_gust":7.27,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}],"pop":0.17},{"dt":1626195600,"temp":27.43,"feels_like":28.39,"pressure":1005,"humidity":57,"dew_point":18.16,"uvi":0.55,"clouds":54,"visibility":10000,"wind_speed":3.91,"wind_deg":53,"wind_gust":8.48,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"pop":0.3},{"dt":1626199200,"temp":25.08,"feels_like":25.39,"pressure":1005,"humidity":67,"dew_point":18.53,"uvi":0.17,"clouds":69,"visibility":10000,"wind_speed":3.87,"wind_deg":45,"wind_gust":9.13,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"pop":0.39,"rain":{"1h":0.17}},{"dt":1626202800,"temp":22.17,"feels_like":22.56,"pressure":1005,"humidity":81,"dew_point":18.77,"uvi":0,"clouds":100,"visibility":10000,"wind_speed":2.61,"wind_deg":65,"wind_gust":5.93,"weather":[{"id":501,"main":"Rain","description":"moderate rain","icon":"10d"}],"pop":0.94,"rain":{"1h":1.49}},{"dt":1626206400,"temp":20.83,"feels_like":21.37,"pressure":1006,"humidity":92,"dew_point":19.47,"uvi":0,"clouds":100,"visibility":3579,"wind_speed":3.23,"wind_deg":185,"wind_gust":7.26,"weather":[{"id":502,"main":"Rain","description":"heavy intensity rain","icon":"10n"}],"pop":1,"rain":{"1h":5.03}},{"dt":1626210000,"temp":19.84,"feels_like":20.41,"pressure":1006,"humidity":97,"dew_point":19.27,"uvi":0,"clouds":100,"visibility":10000,"wind_speed":0.25,"wind_deg":240,"wind_gust":4.25,"weather":[{"id":502,"main":"Rain","description":"heavy intensity rain","icon":"10n"}],"pop":1,"rain":{"1h":5.71}},{"dt":1626213600,"temp":18.53,"feels_like":18.97,"pressure":1007,"humidity":97,"dew_point":18.03,"uvi":0,"clouds":100,"visibility":9194,"wind_speed":3,"wind_deg":94,"wind_gust":5.25,"weather":[{"id":502,"main":"Rain","description":"heavy intensity rain","icon":"10n"}],"pop":1,"rain":{"1h":4.44}},{"dt":1626217200,"temp":17.95,"feels_like":18.28,"pressure":1007,"humidity":95,"dew_point":17.13,"uvi":0,"clouds":100,"visibility":10000,"wind_speed":3.34,"wind_deg":174,"wind_gust":6.32,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"pop":1,"rain":{"1h":0.98}},{"dt":1626220800,"temp":17.37,"feels_like":17.62,"pressure":1008,"humidity":94,"dew_point":16.4,"uvi":0,"clouds":100,"visibility":10000,"wind_speed":4.12,"wind_deg":185,"wind_gust":8.2,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"pop":0.8},{"dt":1626224400,"temp":17.4,"feels_like":17.65,"pressure":1007,"humidity":94,"dew_point":16.38,"uvi":0,"clouds":98,"visibility":10000,"wind_speed":3.54,"wind_deg":203,"wind_gust":7.23,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"pop":0.3},{"dt":1626228000,"temp":16.77,"feels_like":16.96,"pressure":1007,"humidity":94,"dew_point":15.71,"uvi":0,"clouds":90,"visibility":10000,"wind_speed":3.91,"wind_deg":205,"wind_gust":7.48,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"pop":0.12},{"dt":1626231600,"temp":16.71,"feels_like":16.89,"pressure":1007,"humidity":94,"dew_point":15.61,"uvi":0,"clouds":93,"visibility":10000,"wind_speed":4.28,"wind_d ...

# %%
'''
url = "https://api.openweathermap.org/data/2.5/onecall?lat=33.44&lon=-94.04&exclude=hourly,daily&appid=OMW_KEY"
with requests.get(url, stream=True) as r:
    r.raise_for_status() #shows html error if arises
    for chunk in r.iter_content(chunk_size=100): #in bytes (1MB = million iters)
        #or r.iter_lines() #parses line by line
        print(chunk)
'''
# Out:
# '\nurl = "https://api.openweathermap.org/data/2.5/onecall?lat=33.44&lon=-94.04&exclude=hourly,daily&appid=8c159bf63b964af1e78ca3be1ff3e86d"\nwith requests.get(url, stream=True) as r:\n    r.raise_for_status() #shows html error if arises\n    for chunk in r.iter_content(chunk_size=100): #in bytes (1MB = million iters)\n        #or r.iter_lines() #parses line by line\n        print(chunk)\n'

# %% [markdown]
# ## 1.2 Weather API

# %%
url = f"http://api.weatherapi.com/v1/forecast.json?key={os.environ['WAPI_KEY']}&q=Leipzig&days=7&aqi=no&alerts=no"
print(url)
response_wapi = requests.request("GET", url)
print(response_wapi.text)
# Out:
# http://api.weatherapi.com/v1/forecast.json?key=1ce05a0c63b54afc88495153211307&q=Leipzig&days=7&aqi=no&alerts=no
# {"location":{"name":"Leipzig","region":"Sachsen","country":"Germany","lat":51.3,"lon":12.33,"tz_id":"Europe/Berlin","localtime_epoch":1626193910,"localtime":"2021-07-13 18:31"},"current":{"last_updated_epoch":1626192900,"last_updated":"2021-07-13 18:15","temp_c":27.0,"temp_f":80.6,"is_day":1,"condition":{"text":"Sunny","icon":"//cdn.weatherapi.com/weather/64x64/day/113.png","code":1000},"wind_mph":6.9,"wind_kph":11.2,"wind_degree":60,"wind_dir":"ENE","pressure_mb":1007.0,"pressure_in":30.2,"precip_mm":0.0,"precip_in":0.0,"humidity":51,"cloud":0,"feelslike_c":27.9,"feelslike_f":82.1,"vis_km":10.0,"vis_miles":6.0,"uv":7.0,"gust_mph":11.4,"gust_kph":18.4},"forecast":{"forecastday":[{"date":"2021-07-13","date_epoch":1626134400,"day":{"maxtemp_c":27.9,"maxtemp_f":82.2,"mintemp_c":16.5,"mintemp_f":61.7,"avgtemp_c":22.2,"avgtemp_f":72.0,"maxwind_mph":9.8,"maxwind_kph":15.8,"totalprecip_mm":0.1,"totalprecip_in":0.0,"avgvis_km":10.0,"avgvis_miles":6.0,"avghumidity":68.0,"daily_will_it_rain":0,"daily_chance_of_rain":"0","daily_will_it_snow":0,"daily_chance_of_snow":"0","condition":{"text":"Partly cloudy","icon":"//cdn.weatherapi.com/weather/64x64/day/116.png","code":1003},"uv":7.0},"astro":{"sunrise":"05:10 AM","sunset":"09:22 PM","moonrise":"08:30 AM","moonset":"11:36 PM","moon_phase":"First Quarter","moon_illumination":"34"},"hour":[{"time_epoch":1626127200,"time":"2021-07-13 00:00","temp_c":17.7,"temp_f":63.9,"is_day":0,"condition":{"text":"Partly cloudy","icon":"//cdn.weatherapi.com/weather/64x64/night/116.png","code":1003},"wind_mph":4.9,"wind_kph":7.9,"wind_degree":116,"wind_dir":"ESE","pressure_mb":1010.0,"pressure_in":30.3,"precip_mm":0.0,"precip_in":0.0,"humidity":79,"cloud":11,"feelslike_c":17.7,"feelslike_f":63.9,"windchill_c":17.7,"windchill_f":63.9,"heatindex_c":17.7,"heatindex_f":63.9,"dewpoint_c":14.0,"dewpoint_f":57.2,"will_it_rain":0,"chance_of_rain":"0","will_it_snow":0,"chance_of_snow":"0","vis_km":10.0,"vis_miles":6.0,"gust_mph":10.5,"gust_kph":16.9,"uv":1.0},{"time_epoch":1626130800,"time":"2021-07-13 01:00","temp_c":17.1,"temp_f":62.8,"is_day":0,"condition":{"text":"Partly cloudy","icon":"//cdn.weatherapi.com/weather/64x64/night/116.png","code":1003},"wind_mph":4.0,"wind_kph":6.5,"wind_degree":130,"wind_dir":"SE","pressure_mb":1010.0,"pressure_in":30.3,"precip_mm":0.0,"precip_in":0.0,"humidity":80,"cloud":10,"feelslike_c":17.1,"feelslike_f":62.8,"windchill_c":17.1,"windchill_f":62.8,"heatindex_c":17.1,"heatindex_f":62.8,"dewpoint_c":13.6,"dewpoint_f":56.5,"will_it_rain":0,"chance_of_rain":"0","will_it_snow":0,"chance_of_snow":"0","vis_km":10.0,"vis_miles":6.0,"gust_mph":8.5,"gust_kph":13.7,"uv":1.0},{"time_epoch":1626134400,"time":"2021-07-13 02:00","temp_c":16.9,"temp_f":62.4,"is_day":0,"condition":{"text":"Partly cloudy","icon":"//cdn.weatherapi.com/weather/64x64/night/116.png","code":1003},"wind_mph":4.0,"wind_kph":6.5,"wind_degree":118,"wind_dir":"ESE","pressure_mb":1010.0,"pressure_in":30.3,"precip_mm":0.0,"precip_in":0.0,"humidity":80,"cloud":17,"feelslike_c":16.9,"feelslike_f":62.4,"windchill_c":16.9,"windchill_f":62.4,"heatindex_c":16.9,"heatindex_f":62.4,"dewpoint_c":13.5,"dewpoint_f":56.3,"will_it_rain":0,"chance_of_rain":"0","will_it_snow":0,"chance_of_snow":"0","vis_km":10.0,"vis_miles":6.0,"gust_mph":8.3,"gust_kph":13.3,"uv":1.0},{"time_epoch":1626138000,"time":"2021-07-13 03:00","temp_c":16.7,"temp_f":62.1,"is_day":0,"condition":{"text":"Partly cloudy","icon":"//cdn.weatherapi.com/weather/64x64/night/116.png","code":1003},"wind_mph":3.8,"wind_kph":6.1,"wind_degree":106,"wind_dir":"ESE","pressure_mb":1010.0,"pressure_in":30.3,"precip_mm":0.0,"precip_in":0.0,"humidity":81,"cloud":24,"feelslike_c":16.7,"feelslike_f":62.1,"windchill_c":16.7,"windchill_f":62.1,"heatindex_c":16.7,"heatindex_f":62.1,"dewpoint_c":13.4,"dewpoint_f":56.1,"will_it_rain":0,"chance_of_rain":"0","will_it_snow":0,"chance_of_snow":"0","vis_km":10.0,"vis_miles":6.0,"gust_mph":8.3,"gust_kph":13.3,"uv":1.0},{"time_epoch":1626141600,"tim ...

# %% [markdown]
# ## 1.3 Load in pandas

# %%
import pandas as pd
import json

# %% [markdown]
# ### 1.3.1 Weather API

# %%
wapi_json = json.loads(response_wapi.text) #returns dict
print(json.dumps(wapi_json, indent=2)) #returns str (pretty print)
wapi_json.keys() #dict_keys(['location', 'current', 'forecast'])
# Out:
# dict_keys(['location', 'current', 'forecast'])

# %%
wapi_fc_day_df = pd.json_normalize(wapi_json["forecast"]["forecastday"])
print(wapi_fc_day_df.columns)
wapi_fc_day_df
# Out:
# Index(['date', 'date_epoch', 'hour', 'day.maxtemp_c', 'day.maxtemp_f',
#        'day.mintemp_c', 'day.mintemp_f', 'day.avgtemp_c', 'day.avgtemp_f',
#        'day.maxwind_mph', 'day.maxwind_kph', 'day.totalprecip_mm',
#        'day.totalprecip_in', 'day.avgvis_km', 'day.avgvis_miles',
#        'day.avghumidity', 'day.daily_will_it_rain', 'day.daily_chance_of_rain',
#        'day.daily_will_it_snow', 'day.daily_chance_of_snow',
#        'day.condition.text', 'day.condition.icon', 'day.condition.code',
#        'day.uv', 'astro.sunrise', 'astro.sunset', 'astro.moonrise',
#        'astro.moonset', 'astro.moon_phase', 'astro.moon_illumination'],
#       dtype='object')
#          date  date_epoch                                               hour  \
# 0  2021-07-13  1626134400  [{'time_epoch': 1626127200, 'time': '2021-07-1...
# 1  2021-07-14  1626220800  [{'time_epoch': 1626213600, 'time': '2021-07-1...
# 2  2021-07-15  1626307200  [{'time_epoch': 1626300000, 'time': '2021-07-1...
#
#    day.maxtemp_c  day.maxtemp_f  day.mintemp_c  day.mintemp_f  day.avgtemp_c  \
# 0           27.9           82.2           16.5           61.7           22.2
# 1           21.8           71.2           15.6           60.1           18.9
# 2           23.8           74.8           13.5           56.3           18.9
#
#    day.avgtemp_f  day.maxwind_mph  ...  day.condition.text  \
# 0           72.0              9.8  ...       Partly cloudy
# 1           66.0             13.9  ...       Moderate rain
# 2           66.0             11.0  ...       Partly cloudy
#
#                                day.condition.icon  day.condition.code  day.uv  \
# 0  //cdn.weatherapi.com/weather/64x64/day/116.png                1003     7.0
# 1  //cdn.weatherapi.com/weather/64x64/day/302.png                1189     4.0
# 2  //cdn.weatherapi.com/weather/64x64/day/116.png                1003     4.0
#
#    astro.sunrise  astro.sunset  astro.moonrise astro.moonset  \
# 0       05:10 AM      09:22 PM        08:30 AM      11:36 PM
# 1       05:11 AM      09:21 PM        09:48 AM      11:54 PM
# 2       05:12 AM      09:20 PM        11:05 AM    No moonset
#
#    astro.moon_phase astro.moon_illumination
# 0     First Quarter                      34
# 1     First Quarter                      41
# 2     First Quarter                      48
#
# [3 rows x 30 columns]

# %%
#wapi_fc_hr_df = pd.json_normalize(list(wapi_day_df['hour'][0]))
wapi_fc_hr_df = pd.json_normalize(wapi_json["forecast"]["forecastday"],
                                  record_path=['hour'],
                                  meta=['date'],)
print(wapi_fc_hr_df.columns)
wapi_fc_hr_df.sample(5)
# Out:
# Index(['time_epoch', 'time', 'temp_c', 'temp_f', 'is_day', 'wind_mph',
#        'wind_kph', 'wind_degree', 'wind_dir', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feelslike_c',
#        'feelslike_f', 'windchill_c', 'windchill_f', 'heatindex_c',
#        'heatindex_f', 'dewpoint_c', 'dewpoint_f', 'will_it_rain',
#        'chance_of_rain', 'will_it_snow', 'chance_of_snow', 'vis_km',
#        'vis_miles', 'gust_mph', 'gust_kph', 'uv', 'condition.text',
#        'condition.icon', 'condition.code', 'date'],
#       dtype='object')
#     time_epoch              time  temp_c  temp_f  is_day  wind_mph  wind_kph  \
# 28  1626228000  2021-07-14 04:00    17.4    63.3       0       4.5       7.2
# 20  1626199200  2021-07-13 20:00    23.4    74.1       1       7.4      11.9
# 36  1626256800  2021-07-14 12:00    20.5    68.9       1      12.5      20.2
# 45  1626289200  2021-07-14 21:00    16.8    62.2       1       6.9      11.2
# 15  1626181200  2021-07-13 15:00    27.5    81.5       1       9.2      14.8
#
#     wind_degree wind_dir  pressure_mb  ...  chance_of_snow  vis_km  vis_miles  \
# 28          214       SW       1008.0  ...               0    10.0        6.0
# 20           57      ENE       1007.0  ...               0    10.0        6.0
# 36          193      SSW       1010.0  ...               0    10.0        6.0
# 45          232       SW       1012.0  ...               0    10.0        6.0
# 15           71      ENE       1007.0  ...               0    10.0        6.0
#
#     gust_mph  gust_kph   uv        condition.text  \
# 28       7.4      11.9  1.0     Light rain shower
# 20      15.4      24.8  5.0  Patchy rain possible
# 36      15.7      25.2  5.0     Light rain shower
# 45      13.2      21.2  5.0         Partly cloudy
# 15      11.4      18.4  7.0         Partly cloudy
#
#                                       condition.icon  condition.code  \
# 28  //cdn.weatherapi.com/weather/64x64/night/353.png            1240
# 20    //cdn.weatherapi.com/weather/64x64/day/176.png            1063
# 36    //cdn.weatherapi.com/weather/64x64/day/353.png            1240
# 45    //cdn.weatherapi.com/weather/64x64/day/116.png            1003
# 15    //cdn.weatherapi.com/weather/64x64/day/116.png            1003
#
#           date
# 28  2021-07-14
# 20  2021-07-13
# 36  2021-07-14
# 45  2021-07-14
# 15  2021-07-13
#
# [5 rows x 36 columns]

# %% [markdown]
# ### 1.3.2 Open Weather Map

# %%
owm_json = json.loads(response_owm.text)
print(json.dumps(owm_json, indent=2))
# Out:
# {
#   "lat": 51.3396,
#   "lon": 12.3713,
#   "timezone": "Europe/Berlin",
#   "timezone_offset": 7200,
#   "hourly": [
#     {
#       "dt": 1626184800,
#       "temp": 29.47,
#       "feels_like": 29.42,
#       "pressure": 1006,
#       "humidity": 43,
#       "dew_point": 15.59,
#       "uvi": 4.16,
#       "clouds": 20,
#       "visibility": 10000,
#       "wind_speed": 4.18,
#       "wind_deg": 77,
#       "wind_gust": 5.65,
#       "weather": [
#         {
#           "id": 801,
#           "main": "Clouds",
#           "description": "few clouds",
#           "icon": "02d"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626188400,
#       "temp": 29.19,
#       "feels_like": 29.43,
#       "pressure": 1006,
#       "humidity": 46,
#       "dew_point": 16.39,
#       "uvi": 2.71,
#       "clouds": 28,
#       "visibility": 10000,
#       "wind_speed": 4.42,
#       "wind_deg": 63,
#       "wind_gust": 5.61,
#       "weather": [
#         {
#           "id": 802,
#           "main": "Clouds",
#           "description": "scattered clouds",
#           "icon": "03d"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626192000,
#       "temp": 28.53,
#       "feels_like": 29.07,
#       "pressure": 1006,
#       "humidity": 50,
#       "dew_point": 17.1,
#       "uvi": 1.25,
#       "clouds": 40,
#       "visibility": 10000,
#       "wind_speed": 4.31,
#       "wind_deg": 57,
#       "wind_gust": 7.27,
#       "weather": [
#         {
#           "id": 802,
#           "main": "Clouds",
#           "description": "scattered clouds",
#           "icon": "03d"
#         }
#       ],
#       "pop": 0.17
#     },
#     {
#       "dt": 1626195600,
#       "temp": 27.43,
#       "feels_like": 28.39,
#       "pressure": 1005,
#       "humidity": 57,
#       "dew_point": 18.16,
#       "uvi": 0.55,
#       "clouds": 54,
#       "visibility": 10000,
#       "wind_speed": 3.91,
#       "wind_deg": 53,
#       "wind_gust": 8.48,
#       "weather": [
#         {
#           "id": 803,
#           "main": "Clouds",
#           "description": "broken clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0.3
#     },
#     {
#       "dt": 1626199200,
#       "temp": 25.08,
#       "feels_like": 25.39,
#       "pressure": 1005,
#       "humidity": 67,
#       "dew_point": 18.53,
#       "uvi": 0.17,
#       "clouds": 69,
#       "visibility": 10000,
#       "wind_speed": 3.87,
#       "wind_deg": 45,
#       "wind_gust": 9.13,
#       "weather": [
#         {
#           "id": 500,
#           "main": "Rain",
#           "description": "light rain",
#           "icon": "10d"
#         }
#       ],
#       "pop": 0.39,
#       "rain": {
#         "1h": 0.17
#       }
#     },
#     {
#       "dt": 1626202800,
#       "temp": 22.17,
#       "feels_like": 22.56,
#       "pressure": 1005,
#       "humidity": 81,
#       "dew_point": 18.77,
#       "uvi": 0,
#       "clouds": 100,
#       "visibility": 10000,
#       "wind_speed": 2.61,
#       "wind_deg": 65,
#       "wind_gust": 5.93,
#       "weather": [
#         {
#           "id": 501,
#           "main": "Rain",
#           "description": "moderate rain",
#           "icon": "10d"
#         }
#       ],
#       "pop": 0.94,
#       "rain": {
#         "1h": 1.49
#       }
#     },
#     {
#       "dt": 1626206400,
#       "temp": 20.83,
#       "feels_like": 21.37,
#       "pressure": 1006,
#       "humidity": 92,
#       "dew_point": 19.47,
#       "uvi": 0,
#       "clouds": 100,
#       "visibility": 3579,
#       "wind_speed": 3.23,
#       "wind_deg": 185,
#       "wind_gust": 7.26,
#       "weather": [
#         {
#           "id": 502,
#           "main": "Rain",
#           "description": "heavy intensity rain",
#           "icon": "10n"
#         }
#       ],
#       "pop": 1,
#       "rain": {
#         "1h": 5.03
#       }
#     },
#     {
#       "dt": 1626210000,
#       "temp": 19.84,
#       "feels_like": 20.41,
#       "pressure": 1006,
#       "humidity": 97,
#       "dew_point": 19.27,
#       "uvi": 0,
#       "clouds": 100,
#       "visibility": 10000,
#       "wind_speed": 0.25,
#       "wind_deg": 240,
#       "wind_gust": 4.25,
#       "weather": [
#         {
#           "id": 502,
#           "main": "Rain",
#           "description": "heavy intensity rain",
#           "icon": "10n"
#         }
#       ],
#       "pop": 1,
#       "rain": {
#         "1h": 5.71
#       }
#     },
#     {
#       "dt": 1626213600,
#       "temp": 18.53,
#       "feels_like": 18.97,
#       "pressure": 1007,
#       "humidity": 97,
#       "dew_point": 18.03,
#       "uvi": 0,
#       "clouds": 100,
#       "visibility": 9194,
#       "wind_speed": 3,
#       "wind_deg": 94,
#       "wind_gust": 5.25,
#       "weather": [
#         {
#           "id": 502,
#           "main": "Rain",
#           "description": "heavy intensity rain",
#           "icon": "10n"
#         }
#       ],
#       "pop": 1,
#       "rain": {
#         "1h": 4.44
#       }
#     },
#     {
#       "dt": 1626217200,
#       "temp": 17.95,
#       "feels_like": 18.28,
#       "pressure": 1007,
#       "humidity": 95,
#       "dew_point": 17.13,
#       "uvi": 0,
#       "clouds": 100,
#       "visibility": 10000,
#       "wind_speed": 3.34,
#       "wind_deg": 174,
#       "wind_gust": 6.32,
#       "weather": [
#         {
#           "id": 500,
#           "main": "Rain",
#           "description": "light rain",
#           "icon": "10n"
#         }
#       ],
#       "pop": 1,
#       "rain": {
#         "1h": 0.98
#       }
#     },
#     {
#       "dt": 1626220800,
#       "temp": 17.37,
#       "feels_like": 17.62,
#       "pressure": 1008,
#       "humidity": 94,
#       "dew_point": 16.4,
#       "uvi": 0,
#       "clouds": 100,
#       "visibility": 10000,
#       "wind_speed": 4.12,
#       "wind_deg": 185,
#       "wind_gust": 8.2,
#       "weather": [
#         {
#           "id": 804,
#           "main": "Clouds",
#           "description": "overcast clouds",
#           "icon": "04n"
#         }
#       ],
#       "pop": 0.8
#     },
#     {
#       "dt": 1626224400,
#       "temp": 17.4,
#       "feels_like": 17.65,
#       "pressure": 1007,
#       "humidity": 94,
#       "dew_point": 16.38,
#       "uvi": 0,
#       "clouds": 98,
#       "visibility": 10000,
#       "wind_speed": 3.54,
#       "wind_deg": 203,
#       "wind_gust": 7.23,
#       "weather": [
#         {
#           "id": 804,
#           "main": "Clouds",
#           "description": "overcast clouds",
#           "icon": "04n"
#         }
#       ],
#       "pop": 0.3
#     },
#     {
#       "dt": 1626228000,
#       "temp": 16.77,
#       "feels_like": 16.96,
#       "pressure": 1007,
#       "humidity": 94,
#       "dew_point": 15.71,
#       "uvi": 0,
#       "clouds": 90,
#       "visibility": 10000,
#       "wind_speed": 3.91,
#       "wind_deg": 205,
#       "wind_gust": 7.48,
#       "weather": [
#         {
#           "id": 804,
#           "main": "Clouds",
#           "description": "overcast clouds",
#           "icon": "04n"
#         }
#       ],
#       "pop": 0.12
#     },
#     {
#       "dt": 1626231600,
#       "temp": 16.71,
#       "feels_like": 16.89,
#       "pressure": 1007,
#       "humidity": 94,
#       "dew_point": 15.61,
#       "uvi": 0,
#       "clouds": 93,
#       "visibility": 10000,
#       "wind_speed": 4.28,
#       "wind_deg": 202,
#       "wind_gust": 7.75,
#       "weather": [
#         {
#           "id": 804,
#           "main": "Clouds",
#           "description": "overcast clouds",
#           "icon": "04n"
#         }
#       ],
#       "pop": 0.15
#     },
#     {
#       "dt": 1626235200,
#       "temp": 16.39,
#       "feels_like": 16.49,
#       "pressure": 1007,
#       "humidity": 92,
#       "dew_point": 15.16,
#       "uvi": 0.03,
#       "clouds": 95,
#       "visibility": 10000,
#       "wind_speed": 5.24,
#       "wind_deg": 207,
#       "wind_gust": 8.89,
#       "weather": [
#         {
#           "id": 804,
#           "main": "Clouds",
#           "description": "overcast clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0.13
#     },
#     {
#       "dt": 1626238800,
#       "temp": 16.42,
#       "feels_like": 16.47,
#       "pressure": 1008,
#       "humidity": 90,
#       "dew_point": 14.82,
#       "uvi": 0.12,
#       "clouds": 94,
#       "visibility": 10000,
#       "wind_speed": 5.46,
#       "wind_deg": 210,
#       "wind_gust": 8.99,
#       "weather": [
#         {
#           "id": 804,
#           "main": "Clouds",
#           "description": "overcast clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0.08
#     },
#     {
#       "dt": 1626242400,
#       "temp": 16.97,
#       "feels_like": 16.97,
#       "pressure": 1008,
#       "humidity": 86,
#       "dew_point": 14.66,
#       "uvi": 0.29,
#       "clouds": 93,
#       "visibility": 10000,
#       "wind_speed": 5.51,
#       "wind_deg": 212,
#       "wind_gust": 8.54,
#       "weather": [
#         {
#           "id": 804,
#           "main": "Clouds",
#           "description": "overcast clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0.06
#     },
#     {
#       "dt": 1626246000,
#       "temp": 17.94,
#       "feels_like": 17.93,
#       "pressure": 1008,
#       "humidity": 82,
#       "dew_point": 14.76,
#       "uvi": 0.33,
#       "clouds": 81,
#       "visibility": 10000,
#       "wind_speed": 5.15,
#       "wind_deg": 223,
#       "wind_gust": 6.52,
#       "weather": [
#         {
#           "id": 803,
#           "main": "Clouds",
#           "description": "broken clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626249600,
#       "temp": 19.32,
#       "feels_like": 19.32,
#       "pressure": 1009,
#       "humidity": 77,
#       "dew_point": 15.2,
#       "uvi": 0.54,
#       "clouds": 83,
#       "visibility": 10000,
#       "wind_speed": 5.51,
#       "wind_deg": 217,
#       "wind_gust": 6.4,
#       "weather": [
#         {
#           "id": 803,
#           "main": "Clouds",
#           "description": "broken clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626253200,
#       "temp": 19.58,
#       "feels_like": 19.53,
#       "pressure": 1009,
#       "humidity": 74,
#       "dew_point": 14.74,
#       "uvi": 0.76,
#       "clouds": 89,
#       "visibility": 10000,
#       "wind_speed": 5.07,
#       "wind_deg": 214,
#       "wind_gust": 5.88,
#       "weather": [
#         {
#           "id": 804,
#           "main": "Clouds",
#           "description": "overcast clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626256800,
#       "temp": 20.12,
#       "feels_like": 20.02,
#       "pressure": 1009,
#       "humidity": 70,
#       "dew_point": 14.62,
#       "uvi": 1.94,
#       "clouds": 91,
#       "visibility": 10000,
#       "wind_speed": 5.39,
#       "wind_deg": 212,
#       "wind_gust": 6.13,
#       "weather": [
#         {
#           "id": 804,
#           "main": "Clouds",
#           "description": "overcast clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626260400,
#       "temp": 20.97,
#       "feels_like": 20.87,
#       "pressure": 1009,
#       "humidity": 67,
#       "dew_point": 14.54,
#       "uvi": 2.11,
#       "clouds": 88,
#       "visibility": 10000,
#       "wind_speed": 5.7,
#       "wind_deg": 217,
#       "wind_gust": 6.79,
#       "weather": [
#         {
#           "id": 804,
#           "main": "Clouds",
#           "description": "overcast clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626264000,
#       "temp": 21.76,
#       "feels_like": 21.66,
#       "pressure": 1009,
#       "humidity": 64,
#       "dew_point": 14.49,
#       "uvi": 2.04,
#       "clouds": 82,
#       "visibility": 10000,
#       "wind_speed": 4.91,
#       "wind_deg": 223,
#       "wind_gust": 6.12,
#       "weather": [
#         {
#           "id": 803,
#           "main": "Clouds",
#           "description": "broken clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626267600,
#       "temp": 21.24,
#       "feels_like": 21.14,
#       "pressure": 1010,
#       "humidity": 66,
#       "dew_point": 14.57,
#       "uvi": 3.59,
#       "clouds": 99,
#       "visibility": 10000,
#       "wind_speed": 3.83,
#       "wind_deg": 210,
#       "wind_gust": 5.56,
#       "weather": [
#         {
#           "id": 804,
#           "main": "Clouds",
#           "description": "overcast clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626271200,
#       "temp": 22.2,
#       "feels_like": 22.09,
#       "pressure": 1010,
#       "humidity": 62,
#       "dew_point": 14.49,
#       "uvi": 2.71,
#       "clouds": 83,
#       "visibility": 10000,
#       "wind_speed": 4.59,
#       "wind_deg": 211,
#       "wind_gust": 5.51,
#       "weather": [
#         {
#           "id": 803,
#           "main": "Clouds",
#           "description": "broken clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626274800,
#       "temp": 22.35,
#       "feels_like": 22.21,
#       "pressure": 1010,
#       "humidity": 60,
#       "dew_point": 14.18,
#       "uvi": 1.76,
#       "clouds": 73,
#       "visibility": 10000,
#       "wind_speed": 4.92,
#       "wind_deg": 210,
#       "wind_gust": 5.75,
#       "weather": [
#         {
#           "id": 803,
#           "main": "Clouds",
#           "description": "broken clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0.06
#     },
#     {
#       "dt": 1626278400,
#       "temp": 21.83,
#       "feels_like": 21.71,
#       "pressure": 1010,
#       "humidity": 63,
#       "dew_point": 14.52,
#       "uvi": 1.47,
#       "clouds": 63,
#       "visibility": 10000,
#       "wind_speed": 4.34,
#       "wind_deg": 217,
#       "wind_gust": 5.44,
#       "weather": [
#         {
#           "id": 803,
#           "main": "Clouds",
#           "description": "broken clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0.16
#     },
#     {
#       "dt": 1626282000,
#       "temp": 20.65,
#       "feels_like": 20.65,
#       "pressure": 1010,
#       "humidity": 72,
#       "dew_point": 15.4,
#       "uvi": 0.64,
#       "clouds": 55,
#       "visibility": 10000,
#       "wind_speed": 4.13,
#       "wind_deg": 227,
#       "wind_gust": 5.73,
#       "weather": [
#         {
#           "id": 803,
#           "main": "Clouds",
#           "description": "broken clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0.16
#     },
#     {
#       "dt": 1626285600,
#       "temp": 19.24,
#       "feels_like": 19.26,
#       "pressure": 1010,
#       "humidity": 78,
#       "dew_point": 15.16,
#       "uvi": 0.2,
#       "clouds": 49,
#       "visibility": 10000,
#       "wind_speed": 3.41,
#       "wind_deg": 220,
#       "wind_gust": 6.52,
#       "weather": [
#         {
#           "id": 802,
#           "main": "Clouds",
#           "description": "scattered clouds",
#           "icon": "03d"
#         }
#       ],
#       "pop": 0.16
#     },
#     {
#       "dt": 1626289200,
#       "temp": 17.22,
#       "feels_like": 17.19,
#       "pressure": 1011,
#       "humidity": 84,
#       "dew_point": 14.5,
#       "uvi": 0,
#       "clouds": 0,
#       "visibility": 10000,
#       "wind_speed": 2.72,
#       "wind_deg": 189,
#       "wind_gust": 4.02,
#       "weather": [
#         {
#           "id": 800,
#           "main": "Clear",
#           "description": "clear sky",
#           "icon": "01d"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626292800,
#       "temp": 15.77,
#       "feels_like": 15.73,
#       "pressure": 1011,
#       "humidity": 89,
#       "dew_point": 13.86,
#       "uvi": 0,
#       "clouds": 3,
#       "visibility": 10000,
#       "wind_speed": 2.65,
#       "wind_deg": 185,
#       "wind_gust": 4.12,
#       "weather": [
#         {
#           "id": 800,
#           "main": "Clear",
#           "description": "clear sky",
#           "icon": "01n"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626296400,
#       "temp": 15.08,
#       "feels_like": 14.97,
#       "pressure": 1011,
#       "humidity": 89,
#       "dew_point": 13.28,
#       "uvi": 0,
#       "clouds": 10,
#       "visibility": 10000,
#       "wind_speed": 2.8,
#       "wind_deg": 183,
#       "wind_gust": 4.42,
#       "weather": [
#         {
#           "id": 800,
#           "main": "Clear",
#           "description": "clear sky",
#           "icon": "01n"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626300000,
#       "temp": 14.74,
#       "feels_like": 14.57,
#       "pressure": 1011,
#       "humidity": 88,
#       "dew_point": 12.77,
#       "uvi": 0,
#       "clouds": 9,
#       "visibility": 10000,
#       "wind_speed": 2.79,
#       "wind_deg": 169,
#       "wind_gust": 4.09,
#       "weather": [
#         {
#           "id": 800,
#           "main": "Clear",
#           "description": "clear sky",
#           "icon": "01n"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626303600,
#       "temp": 14.35,
#       "feels_like": 14.14,
#       "pressure": 1011,
#       "humidity": 88,
#       "dew_point": 12.46,
#       "uvi": 0,
#       "clouds": 8,
#       "visibility": 10000,
#       "wind_speed": 2.12,
#       "wind_deg": 148,
#       "wind_gust": 2.29,
#       "weather": [
#         {
#           "id": 800,
#           "main": "Clear",
#           "description": "clear sky",
#           "icon": "01n"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626307200,
#       "temp": 14.15,
#       "feels_like": 13.92,
#       "pressure": 1011,
#       "humidity": 88,
#       "dew_point": 12.19,
#       "uvi": 0,
#       "clouds": 8,
#       "visibility": 10000,
#       "wind_speed": 1.73,
#       "wind_deg": 138,
#       "wind_gust": 1.79,
#       "weather": [
#         {
#           "id": 800,
#           "main": "Clear",
#           "description": "clear sky",
#           "icon": "01n"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626310800,
#       "temp": 14.07,
#       "feels_like": 13.8,
#       "pressure": 1011,
#       "humidity": 87,
#       "dew_point": 11.96,
#       "uvi": 0,
#       "clouds": 2,
#       "visibility": 10000,
#       "wind_speed": 2.25,
#       "wind_deg": 123,
#       "wind_gust": 2.3,
#       "weather": [
#         {
#           "id": 800,
#           "main": "Clear",
#           "description": "clear sky",
#           "icon": "01n"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626314400,
#       "temp": 13.91,
#       "feels_like": 13.63,
#       "pressure": 1011,
#       "humidity": 87,
#       "dew_point": 11.68,
#       "uvi": 0,
#       "clouds": 3,
#       "visibility": 10000,
#       "wind_speed": 2.53,
#       "wind_deg": 133,
#       "wind_gust": 2.86,
#       "weather": [
#         {
#           "id": 800,
#           "main": "Clear",
#           "description": "clear sky",
#           "icon": "01n"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626318000,
#       "temp": 13.69,
#       "feels_like": 13.39,
#       "pressure": 1011,
#       "humidity": 87,
#       "dew_point": 11.5,
#       "uvi": 0,
#       "clouds": 5,
#       "visibility": 10000,
#       "wind_speed": 2.64,
#       "wind_deg": 147,
#       "wind_gust": 3.19,
#       "weather": [
#         {
#           "id": 800,
#           "main": "Clear",
#           "description": "clear sky",
#           "icon": "01n"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626321600,
#       "temp": 13.94,
#       "feels_like": 13.64,
#       "pressure": 1011,
#       "humidity": 86,
#       "dew_point": 11.64,
#       "uvi": 0.03,
#       "clouds": 4,
#       "visibility": 10000,
#       "wind_speed": 2.65,
#       "wind_deg": 122,
#       "wind_gust": 3.86,
#       "weather": [
#         {
#           "id": 800,
#           "main": "Clear",
#           "description": "clear sky",
#           "icon": "01d"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626325200,
#       "temp": 15.57,
#       "feels_like": 15.35,
#       "pressure": 1012,
#       "humidity": 83,
#       "dew_point": 12.62,
#       "uvi": 0.12,
#       "clouds": 17,
#       "visibility": 10000,
#       "wind_speed": 2.39,
#       "wind_deg": 119,
#       "wind_gust": 5.28,
#       "weather": [
#         {
#           "id": 801,
#           "main": "Clouds",
#           "description": "few clouds",
#           "icon": "02d"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626328800,
#       "temp": 17.62,
#       "feels_like": 17.37,
#       "pressure": 1012,
#       "humidity": 74,
#       "dew_point": 13,
#       "uvi": 0.3,
#       "clouds": 24,
#       "visibility": 10000,
#       "wind_speed": 3.21,
#       "wind_deg": 131,
#       "wind_gust": 5.22,
#       "weather": [
#         {
#           "id": 801,
#           "main": "Clouds",
#           "description": "few clouds",
#           "icon": "02d"
#         }
#       ],
#       "pop": 0
#     },
#     {
#       "dt": 1626332400,
#       "temp": 19.07,
#       "feels_like": 18.81,
#       "pressure": 1012,
#       "humidity": 68,
#       "dew_point": 12.95,
#       "uvi": 0.85,
#       "clouds": 39,
#       "visibility": 10000,
#       "wind_speed": 3.72,
#       "wind_deg": 146,
#       "wind_gust": 5.72,
#       "weather": [
#         {
#           "id": 802,
#           "main": "Clouds",
#           "description": "scattered clouds",
#           "icon": "03d"
#         }
#       ],
#       "pop": 0.01
#     },
#     {
#       "dt": 1626336000,
#       "temp": 19.92,
#       "feels_like": 19.66,
#       "pressure": 1012,
#       "humidity": 65,
#       "dew_point": 13.11,
#       "uvi": 1.4,
#       "clouds": 50,
#       "visibility": 10000,
#       "wind_speed": 3.79,
#       "wind_deg": 154,
#       "wind_gust": 5.22,
#       "weather": [
#         {
#           "id": 802,
#           "main": "Clouds",
#           "description": "scattered clouds",
#           "icon": "03d"
#         }
#       ],
#       "pop": 0.01
#     },
#     {
#       "dt": 1626339600,
#       "temp": 20.46,
#       "feels_like": 20.23,
#       "pressure": 1012,
#       "humidity": 64,
#       "dew_point": 13.33,
#       "uvi": 1.95,
#       "clouds": 62,
#       "visibility": 10000,
#       "wind_speed": 4.12,
#       "wind_deg": 153,
#       "wind_gust": 5.49,
#       "weather": [
#         {
#           "id": 803,
#           "main": "Clouds",
#           "description": "broken clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0.01
#     },
#     {
#       "dt": 1626343200,
#       "temp": 21.32,
#       "feels_like": 21.13,
#       "pressure": 1012,
#       "humidity": 62,
#       "dew_point": 13.66,
#       "uvi": 2.25,
#       "clouds": 66,
#       "visibility": 10000,
#       "wind_speed": 4.18,
#       "wind_deg": 158,
#       "wind_gust": 5.67,
#       "weather": [
#         {
#           "id": 803,
#           "main": "Clouds",
#           "description": "broken clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0.01
#     },
#     {
#       "dt": 1626346800,
#       "temp": 21.58,
#       "feels_like": 21.41,
#       "pressure": 1012,
#       "humidity": 62,
#       "dew_point": 13.83,
#       "uvi": 2.44,
#       "clouds": 71,
#       "visibility": 10000,
#       "wind_speed": 4.1,
#       "wind_deg": 162,
#       "wind_gust": 5.51,
#       "weather": [
#         {
#           "id": 803,
#           "main": "Clouds",
#           "description": "broken clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0.01
#     },
#     {
#       "dt": 1626350400,
#       "temp": 20.8,
#       "feels_like": 20.66,
#       "pressure": 1013,
#       "humidity": 66,
#       "dew_point": 14.21,
#       "uvi": 2.35,
#       "clouds": 76,
#       "visibility": 10000,
#       "wind_speed": 3.65,
#       "wind_deg": 181,
#       "wind_gust": 4.53,
#       "weather": [
#         {
#           "id": 803,
#           "main": "Clouds",
#           "description": "broken clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0.01
#     },
#     {
#       "dt": 1626354000,
#       "temp": 21.22,
#       "feels_like": 21.12,
#       "pressure": 1013,
#       "humidity": 66,
#       "dew_point": 14.47,
#       "uvi": 4.15,
#       "clouds": 100,
#       "visibility": 10000,
#       "wind_speed": 3.35,
#       "wind_deg": 179,
#       "wind_gust": 4.08,
#       "weather": [
#         {
#           "id": 804,
#           "main": "Clouds",
#           "description": "overcast clouds",
#           "icon": "04d"
#         }
#       ],
#       "pop": 0.22
#     }
#   ],
#   "daily": [
#     {
#       "dt": 1626174000,
#       "sunrise": 1626145763,
#       "sunset": 1626204164,
#       "moonrise": 1626157800,
#       "moonset": 1626212160,
#       "moon_phase": 0.11,
#       "temp": {
#         "day": 27.02,
#         "min": 16.23,
#         "max": 29.47,
#         "night": 19.84,
#         "eve": 27.43,
#         "morn": 18.02
#       },
#       "feels_like": {
#         "day": 27.69,
#         "night": 20.41,
#         "eve": 28.39,
#         "morn": 17.94
#       },
#       "pressure": 1007,
#       "humidity": 54,
#       "dew_point": 16.92,
#       "wind_speed": 4.43,
#       "wind_deg": 86,
#       "wind_gust": 9.13,
#       "weather": [
#         {
#           "id": 502,
#           "main": "Rain",
#           "description": "heavy intensity rain",
#           "icon": "10d"
#         }
#       ],
#       "clouds": 67,
#       "pop": 1,
#       "rain": 12.4,
#       "uvi": 5.57
#     },
#     {
#       "dt": 1626260400,
#       "sunrise": 1626232231,
#       "sunset": 1626290509,
#       "moonrise": 1626248880,
#       "moonset": 1626299640,
#       "moon_phase": 0.14,
#       "temp": {
#         "day": 20.97,
#         "min": 15.08,
#         "max": 22.35,
#         "night": 15.08,
#         "eve": 20.65,
#         "morn": 16.42
#       },
#       "feels_like": {
#         "day": 20.87,
#         "night": 14.97,
#         "eve": 20.65,
#         "morn": 16.47
#       },
#       "pressure": 1009,
#       "humidity": 67,
#       "dew_point": 14.54,
#       "wind_speed": 5.7,
#       "wind_deg": 217,
#       "wind_gust": 8.99,
#       "weather": [
#         {
#           "id": 502,
#           "main": "Rain",
#           "description": "heavy intensity rain",
#           "icon": "10d"
#         }
#       ],
#       "clouds": 88,
#       "pop": 1,
#       "rain": 5.42,
#       "uvi": 3.59
#     },
#     {
#       "dt": 1626346800,
#       "sunrise": 1626318701,
#       "sunset": 1626376852,
#       "moonrise": 1626339900,
#       "moonset": 0,
#       "moon_phase": 0.18,
#       "temp": {
#         "day": 21.58,
#         "min": 13.69,
#         "max": 21.87,
#         "night": 15.54,
#         "eve": 19.95,
#         "morn": 15.57
#       },
#       "feels_like": {
#         "day": 21.41,
#         "night": 15.45,
#         "eve": 19.91,
#         "morn": 15.35
#       },
#       "pressure": 1012,
#       "humidity": 62,
#       "dew_point": 13.83,
#       "wind_speed": 4.32,
#       "wind_deg": 186,
#       "wind_gust": 5.72,
#       "weather": [
#         {
#           "id": 500,
#           "main": "Rain",
#           "description": "light rain",
#           "icon": "10d"
#         }
#       ],
#       "clouds": 71,
#       "pop": 0.4,
#       "rain": 0.32,
#       "uvi": 4.15
#     },
#     {
#       "dt": 1626433200,
#       "sunrise": 1626405173,
#       "sunset": 1626463192,
#       "moonrise": 1626431040,
#       "moonset": 1626387000,
#       "moon_phase": 0.21,
#       "temp": {
#         "day": 23.01,
#         "min": 13.98,
#         "max": 24.1,
#         "night": 18.69,
#         "eve": 22.84,
#         "morn": 16.01
#       },
#       "feels_like": {
#         "day": 22.91,
#         "night": 18.63,
#         "eve": 22.96,
#         "morn": 15.94
#       },
#       "pressure": 1018,
#       "humidity": 59,
#       "dew_point": 14.6,
#       "wind_speed": 2.86,
#       "wind_deg": 193,
#       "wind_gust": 4.53,
#       "weather": [
#         {
#           "id": 803,
#           "main": "Clouds",
#           "description": "broken clouds",
#           "icon": "04d"
#         }
#       ],
#       "clouds": 61,
#       "pop": 0.01,
#       "uvi": 6.48
#     },
#     {
#       "dt": 1626519600,
#       "sunrise": 1626491646,
#       "sunset": 1626549529,
#       "moonrise": 1626522300,
#       "moonset": 1626474360,
#       "moon_phase": 0.25,
#       "temp": {
#         "day": 27.05,
#         "min": 16.63,
#         "max": 27.05,
#         "night": 20.07,
#         "eve": 23.24,
#         "morn": 19.53
#       },
#       "feels_like": {
#         "day": 27.72,
#         "night": 20.53,
#         "eve": 23.63,
#         "morn": 19.65
#       },
#       "pressure": 1018,
#       "humidity": 54,
#       "dew_point": 16.89,
#       "wind_speed": 4.28,
#       "wind_deg": 335,
#       "wind_gust": 7.86,
#       "weather": [
#         {
#           "id": 500,
#           "main": "Rain",
#           "description": "light rain",
#           "icon": "10d"
#         }
#       ],
#       "clouds": 89,
#       "pop": 0.71,
#       "rain": 2.44,
#       "uvi": 6.04
#     },
#     {
#       "dt": 1626606000,
#       "sunrise": 1626578121,
#       "sunset": 1626635864,
#       "moonrise": 1626613680,
#       "moonset": 1626561780,
#       "moon_phase": 0.29,
#       "temp": {
#         "day": 27.28,
#         "min": 18.15,
#         "max": 27.28,
#         "night": 19.14,
#         "eve": 23.68,
#         "morn": 20.44
#       },
#       "feels_like": {
#         "day": 28.28,
#         "night": 18.99,
#         "eve": 23.77,
#         "morn": 20.86
#       },
#       "pressure": 1018,
#       "humidity": 58,
#       "dew_point": 18.15,
#       "wind_speed": 6.42,
#       "wind_deg": 321,
#       "wind_gust": 10.48,
#       "weather": [
#         {
#           "id": 500,
#           "main": "Rain",
#           "description": "light rain",
#           "icon": "10d"
#         }
#       ],
#       "clouds": 63,
#       "pop": 0.42,
#       "rain": 1,
#       "uvi": 7
#     },
#     {
#       "dt": 1626692400,
#       "sunrise": 1626664597,
#       "sunset": 1626722197,
#       "moonrise": 1626705180,
#       "moonset": 1626649440,
#       "moon_phase": 0.32,
#       "temp": {
#         "day": 20.57,
#         "min": 14.84,
#         "max": 20.57,
#         "night": 16.62,
#         "eve": 17.45,
#         "morn": 15.82
#       },
#       "feels_like": {
#         "day": 20.46,
#         "night": 16.43,
#         "eve": 17.31,
#         "morn": 15.62
#       },
#       "pressure": 1018,
#       "humidity": 68,
#       "dew_point": 14.44,
#       "wind_speed": 6.94,
#       "wind_deg": 319,
#       "wind_gust": 9.33,
#       "weather": [
#         {
#           "id": 802,
#           "main": "Clouds",
#           "description": "scattered clouds",
#           "icon": "03d"
#         }
#       ],
#       "clouds": 34,
#       "pop": 0,
#       "uvi": 7
#     },
#     {
#       "dt": 1626778800,
#       "sunrise": 1626751075,
#       "sunset": 1626808527,
#       "moonrise": 1626796800,
#       "moonset": 1626737340,
#       "moon_phase": 0.36,
#       "temp": {
#         "day": 20.74,
#         "min": 14.82,
#         "max": 22.49,
#         "night": 17.41,
#         "eve": 20.48,
#         "morn": 15.54
#       },
#       "feels_like": {
#         "day": 20.51,
#         "night": 17.24,
#         "eve": 20.44,
#         "morn": 15.32
#       },
#       "pressure": 1017,
#       "humidity": 63,
#       "dew_point": 13.31,
#       "wind_speed": 4.24,
#       "wind_deg": 328,
#       "wind_gust": 7.7,
#       "weather": [
#         {
#           "id": 500,
#           "main": "Rain",
#           "description": "light rain",
#           "icon": "10d"
#         }
#       ],
#       "clouds": 66,
#       "pop": 0.37,
#       "rain": 0.74,
#       "uvi": 7
#     }
#   ]
# }

# %%
owm_json.keys()
# Out:
# dict_keys(['lat', 'lon', 'timezone', 'timezone_offset', 'hourly', 'daily'])

# %%
owm_fc_day_df = pd.json_normalize(owm_json,
                                 record_path=['daily'],
                                 meta=['lat', 'lon'])
print(owm_fc_day_df.columns)
owm_fc_day_df.sample(5)
# Out:
# Index(['dt', 'sunrise', 'sunset', 'moonrise', 'moonset', 'moon_phase',
#        'pressure', 'humidity', 'dew_point', 'wind_speed', 'wind_deg',
#        'wind_gust', 'weather', 'clouds', 'pop', 'rain', 'uvi', 'temp.day',
#        'temp.min', 'temp.max', 'temp.night', 'temp.eve', 'temp.morn',
#        'feels_like.day', 'feels_like.night', 'feels_like.eve',
#        'feels_like.morn', 'lat', 'lon'],
#       dtype='object')
#            dt     sunrise      sunset    moonrise     moonset  moon_phase  \
# 2  1626346800  1626318701  1626376852  1626339900           0        0.18
# 3  1626433200  1626405173  1626463192  1626431040  1626387000        0.21
# 4  1626519600  1626491646  1626549529  1626522300  1626474360        0.25
# 1  1626260400  1626232231  1626290509  1626248880  1626299640        0.14
# 5  1626606000  1626578121  1626635864  1626613680  1626561780        0.29
#
#    pressure  humidity  dew_point  wind_speed  ...  temp.max  temp.night  \
# 2      1012        62      13.83        4.32  ...     21.87       15.54
# 3      1018        59      14.60        2.86  ...     24.10       18.69
# 4      1018        54      16.89        4.28  ...     27.05       20.07
# 1      1009        67      14.54        5.70  ...     22.35       15.08
# 5      1018        58      18.15        6.42  ...     27.28       19.14
#
#   temp.eve  temp.morn  feels_like.day  feels_like.night  feels_like.eve  \
# 2    19.95      15.57           21.41             15.45           19.91
# 3    22.84      16.01           22.91             18.63           22.96
# 4    23.24      19.53           27.72             20.53           23.63
# 1    20.65      16.42           20.87             14.97           20.65
# 5    23.68      20.44           28.28             18.99           23.77
#
#    feels_like.morn      lat      lon
# 2            15.35  51.3396  12.3713
# 3            15.94  51.3396  12.3713
# 4            19.65  51.3396  12.3713
# 1            16.47  51.3396  12.3713
# 5            20.86  51.3396  12.3713
#
# [5 rows x 29 columns]

# %%
pd.json_normalize(owm_fc_day_df.weather[0])
# Out:
#     id  main           description icon
# 0  502  Rain  heavy intensity rain  10d

# %%
owm_fc_hr_df = pd.json_normalize(owm_json,
                                 record_path=['hourly'],
                                 meta=['lat', 'lon'])
owm_fc_hr_df
# Out:
#             dt   temp  feels_like  pressure  humidity  dew_point   uvi  \
# 0   1626184800  29.47       29.42      1006        43      15.59  4.16
# 1   1626188400  29.19       29.43      1006        46      16.39  2.71
# 2   1626192000  28.53       29.07      1006        50      17.10  1.25
# 3   1626195600  27.43       28.39      1005        57      18.16  0.55
# 4   1626199200  25.08       25.39      1005        67      18.53  0.17
# 5   1626202800  22.17       22.56      1005        81      18.77  0.00
# 6   1626206400  20.83       21.37      1006        92      19.47  0.00
# 7   1626210000  19.84       20.41      1006        97      19.27  0.00
# 8   1626213600  18.53       18.97      1007        97      18.03  0.00
# 9   1626217200  17.95       18.28      1007        95      17.13  0.00
# 10  1626220800  17.37       17.62      1008        94      16.40  0.00
# 11  1626224400  17.40       17.65      1007        94      16.38  0.00
# 12  1626228000  16.77       16.96      1007        94      15.71  0.00
# 13  1626231600  16.71       16.89      1007        94      15.61  0.00
# 14  1626235200  16.39       16.49      1007        92      15.16  0.03
# 15  1626238800  16.42       16.47      1008        90      14.82  0.12
# 16  1626242400  16.97       16.97      1008        86      14.66  0.29
# 17  1626246000  17.94       17.93      1008        82      14.76  0.33
# 18  1626249600  19.32       19.32      1009        77      15.20  0.54
# 19  1626253200  19.58       19.53      1009        74      14.74  0.76
# 20  1626256800  20.12       20.02      1009        70      14.62  1.94
# 21  1626260400  20.97       20.87      1009        67      14.54  2.11
# 22  1626264000  21.76       21.66      1009        64      14.49  2.04
# 23  1626267600  21.24       21.14      1010        66      14.57  3.59
# 24  1626271200  22.20       22.09      1010        62      14.49  2.71
# 25  1626274800  22.35       22.21      1010        60      14.18  1.76
# 26  1626278400  21.83       21.71      1010        63      14.52  1.47
# 27  1626282000  20.65       20.65      1010        72      15.40  0.64
# 28  1626285600  19.24       19.26      1010        78      15.16  0.20
# 29  1626289200  17.22       17.19      1011        84      14.50  0.00
# 30  1626292800  15.77       15.73      1011        89      13.86  0.00
# 31  1626296400  15.08       14.97      1011        89      13.28  0.00
# 32  1626300000  14.74       14.57      1011        88      12.77  0.00
# 33  1626303600  14.35       14.14      1011        88      12.46  0.00
# 34  1626307200  14.15       13.92      1011        88      12.19  0.00
# 35  1626310800  14.07       13.80      1011        87      11.96  0.00
# 36  1626314400  13.91       13.63      1011        87      11.68  0.00
# 37  1626318000  13.69       13.39      1011        87      11.50  0.00
# 38  1626321600  13.94       13.64      1011        86      11.64  0.03
# 39  1626325200  15.57       15.35      1012        83      12.62  0.12
# 40  1626328800  17.62       17.37      1012        74      13.00  0.30
# 41  1626332400  19.07       18.81      1012        68      12.95  0.85
# 42  1626336000  19.92       19.66      1012        65      13.11  1.40
# 43  1626339600  20.46       20.23      1012        64      13.33  1.95
# 44  1626343200  21.32       21.13      1012        62      13.66  2.25
# 45  1626346800  21.58       21.41      1012        62      13.83  2.44
# 46  1626350400  20.80       20.66      1013        66      14.21  2.35
# 47  1626354000  21.22       21.12      1013        66      14.47  4.15
#
#     clouds  visibility  wind_speed  wind_deg  wind_gust  \
# 0       20       10000        4.18        77       5.65
# 1       28       10000        4.42        63       5.61
# 2       40       10000        4.31        57       7.27
# 3       54       10000        3.91        53       8.48
# 4       69       10000        3.87        45       9.13
# 5      100       10000        2.61        65       5.93
# 6      100        3579        3.23       185       7.26
# 7      100       10000        0.25       240       4.25
# 8      100        9194        3.00        94       5.25
# 9      100       10000        3.34       174       6.32
# 10     100       10000        4.12       185       8.20
# 11      98       10000        3.54       203       7.23
# 12      90       10000        3.91       205       7.48
# 13      93       10000        4.28       202       7.75
# 14      95       10000        5.24       207       8.89
# 15      94       10000        5.46       210       8.99
# 16      93       10000        5.51       212       8.54
# 17      81       10000        5.15       223       6.52
# 18      83       10000        5.51       217       6.40
# 19      89       10000        5.07       214       5.88
# 20      91       10000        5.39       212       6.13
# 21      88       10000        5.70       217       6.79
# 22      82       10000        4.91       223       6.12
# 23      99       10000        3.83       210       5.56
# 24      83       10000        4.59       211       5.51
# 25      73       10000        4.92       210       5.75
# 26      63       10000        4.34       217       5.44
# 27      55       10000        4.13       227       5.73
# 28      49       10000        3.41       220       6.52
# 29       0       10000        2.72       189       4.02
# 30       3       10000        2.65       185       4.12
# 31      10       10000        2.80       183       4.42
# 32       9       10000        2.79       169       4.09
# 33       8       10000        2.12       148       2.29
# 34       8       10000        1.73       138       1.79
# 35       2       10000        2.25       123       2.30
# 36       3       10000        2.53       133       2.86
# 37       5       10000        2.64       147       3.19
# 38       4       10000        2.65       122       3.86
# 39      17       10000        2.39       119       5.28
# 40      24       10000        3.21       131       5.22
# 41      39       10000        3.72       146       5.72
# 42      50       10000        3.79       154       5.22
# 43      62       10000        4.12       153       5.49
# 44      66       10000        4.18       158       5.67
# 45      71       10000        4.10       162       5.51
# 46      76       10000        3.65       181       4.53
# 47     100       10000        3.35       179       4.08
#
#                                               weather   pop  rain.1h      lat  \
# 0   [{'id': 801, 'main': 'Clouds', 'description': ...  0.00      NaN  51.3396
# 1   [{'id': 802, 'main': 'Clouds', 'description': ...  0.00      NaN  51.3396
# 2   [{'id': 802, 'main': 'Clouds', 'description': ...  0.17      NaN  51.3396
# 3   [{'id': 803, 'main': 'Clouds', 'description': ...  0.30      NaN  51.3396
# 4   [{'id': 500, 'main': 'Rain', 'description': 'l...  0.39     0.17  51.3396
# 5   [{'id': 501, 'main': 'Rain', 'description': 'm...  0.94     1.49  51.3396
# 6   [{'id': 502, 'main': 'Rain', 'description': 'h...  1.00     5.03  51.3396
# 7   [{'id': 502, 'main': 'Rain', 'description': 'h...  1.00     5.71  51.3396
# 8   [{'id': 502, 'main': 'Rain', 'description': 'h...  1.00     4.44  51.3396
# 9   [{'id': 500, 'main': 'Rain', 'description': 'l...  1.00     0.98  51.3396
# 10  [{'id': 804, 'main': 'Clouds', 'description': ...  0.80      NaN  51.3396
# 11  [{'id': 804, 'main': 'Clouds', 'description': ...  0.30      NaN  51.3396
# 12  [{'id': 804, 'main': 'Clouds', 'description': ...  0.12      NaN  51.3396
# 13  [{'id': 804, 'main': 'Clouds', 'description': ...  0.15      NaN  51.3396
# 14  [{'id': 804, 'main': 'Clouds', 'description': ...  0.13      NaN  51.3396
# 15  [{'id': 804, 'main': 'Clouds', 'description': ...  0.08      NaN  51.3396
# 16  [{'id': 804, 'main': 'Clouds', 'description': ...  0.06      NaN  51.3396
# 17  [{'id': 803, 'main': 'Clouds', 'description': ...  0.00      NaN  51.3396
# 18  [{'id': 803, 'main': 'Clouds', 'description': ...  0.00      NaN  51.3396
# 19  [{'id': 804, 'main': 'Clouds', 'description': ...  0.00      NaN  51.3396
# 20  [{'id': 804, 'main': 'Clouds', 'description': ...  0.00      NaN  51.3396
# 21  [{'id': 804, 'main': 'Clouds', 'description': ...  0.00      NaN  51.3396
# 22  [{'id': 803, 'main': 'Clouds', 'description': ...  0.00      NaN  51.3396
# 23  [{'id': 804, 'main': 'Clouds', 'description': ...  0.00      NaN  51.3396
# 24  [{'id': 803, 'main': 'Clouds', 'description': ...  0.00      NaN  51.3396
# 25  [{'id': 803, 'main': 'Clouds', 'description': ...  0.06      NaN  51.3396
# 26  [{'id': 803, 'main': 'Clouds', 'description': ...  0.16      NaN  51.3396
# 27  [{'id': 803, 'main': 'Clouds', 'description': ...  0.16      NaN  51.3396
# 28  [{'id': 802, 'main': 'Clouds', 'description': ...  0.16      NaN  51.3396
# 29  [{'id': 800, 'main': 'Clear', 'description': '...  0.00      NaN  51.3396
# 30  [{'id': 800, 'main': 'Clear', 'description': '...  0.00      NaN  51.3396
# 31  [{'id': 800, 'main': 'Clear', 'description': '...  0.00      NaN  51.3396
# 32  [{'id': 800, 'main': 'Clear', 'description': '...  0.00      NaN  51.3396
# 33  [{'id': 800, 'main': 'Clear', 'description': '...  0.00      NaN  51.3396
# 34  [{'id': 800, 'main': 'Clear', 'description': '...  0.00      NaN  51.3396
# 35  [{'id': 800, 'main': 'Clear', 'description': '...  0.00      NaN  51.3396
# 36  [{'id': 800, 'main': 'Clear', 'description': '...  0.00      NaN  51.3396
# 37  [{'id': 800, 'main': 'Clear', 'description': '...  0.00      NaN  51.3396
# 38  [{'id': 800, 'main': 'Clear', 'description': '...  0.00      NaN  51.3396
# 39  [{'id': 801, 'main': 'Clouds', 'description': ...  0.00      NaN  51.3396
# 40  [{'id': 801, 'main': 'Clouds', 'description': ...  0.00      NaN  51.3396
# 41  [{'id': 802, 'main': 'Clouds', 'description': ...  0.01      NaN  51.3396
# 42  [{'id': 802, 'main': 'Clouds', 'description': ...  0.01      NaN  51.3396
# 43  [{'id': 803, 'main': 'Clouds', 'description': ...  0.01      NaN  51.3396
# 44  [{'id': 803, 'main': 'Clouds', 'description': ...  0.01      NaN  51.3396
# 45  [{'id': 803, 'main': 'Clouds', 'description': ...  0.01      NaN  51.3396
# 46  [{'id': 803, 'main': 'Clouds', 'description': ...  0.01      NaN  51.3396
# 47  [{'id': 804, 'main': 'Clouds', 'description': ...  0.22      NaN  51.3396
#
#         lon
# 0   12.3713
# 1   12.3713
# 2   12.3713
# 3   12.3713
# 4   12.3713
# 5   12.3713
# 6   12.3713
# 7   12.3713
# 8   12.3713
# 9   12.3713
# 10  12.3713
# 11  12.3713
# 12  12.3713
# 13  12.3713
# 14  12.3713
# 15  12.3713
# 16  12.3713
# 17  12.3713
# 18  12.3713
# 19  12.3713
# 20  12.3713
# 21  12.3713
# 22  12.3713
# 23  12.3713
# 24  12.3713
# 25  12.3713
# 26  12.3713
# 27  12.3713
# 28  12.3713
# 29  12.3713
# 30  12.3713
# 31  12.3713
# 32  12.3713
# 33  12.3713
# 34  12.3713
# 35  12.3713
# 36  12.3713
# 37  12.3713
# 38  12.3713
# 39  12.3713
# 40  12.3713
# 41  12.3713
# 42  12.3713
# 43  12.3713
# 44  12.3713
# 45  12.3713
# 46  12.3713
# 47  12.3713

# %%
from time import ctime
as_time=pd.DataFrame(map(ctime, owm_fc_hr_df["dt"]))
pd.to_datetime(as_time[0])
# Out:
# 0    2021-07-13 16:00:00
# 1    2021-07-13 17:00:00
# 2    2021-07-13 18:00:00
# 3    2021-07-13 19:00:00
# 4    2021-07-13 20:00:00
# 5    2021-07-13 21:00:00
# 6    2021-07-13 22:00:00
# 7    2021-07-13 23:00:00
# 8    2021-07-14 00:00:00
# 9    2021-07-14 01:00:00
# 10   2021-07-14 02:00:00
# 11   2021-07-14 03:00:00
# 12   2021-07-14 04:00:00
# 13   2021-07-14 05:00:00
# 14   2021-07-14 06:00:00
# 15   2021-07-14 07:00:00
# 16   2021-07-14 08:00:00
# 17   2021-07-14 09:00:00
# 18   2021-07-14 10:00:00
# 19   2021-07-14 11:00:00
# 20   2021-07-14 12:00:00
# 21   2021-07-14 13:00:00
# 22   2021-07-14 14:00:00
# 23   2021-07-14 15:00:00
# 24   2021-07-14 16:00:00
# 25   2021-07-14 17:00:00
# 26   2021-07-14 18:00:00
# 27   2021-07-14 19:00:00
# 28   2021-07-14 20:00:00
# 29   2021-07-14 21:00:00
# 30   2021-07-14 22:00:00
# 31   2021-07-14 23:00:00
# 32   2021-07-15 00:00:00
# 33   2021-07-15 01:00:00
# 34   2021-07-15 02:00:00
# 35   2021-07-15 03:00:00
# 36   2021-07-15 04:00:00
# 37   2021-07-15 05:00:00
# 38   2021-07-15 06:00:00
# 39   2021-07-15 07:00:00
# 40   2021-07-15 08:00:00
# 41   2021-07-15 09:00:00
# 42   2021-07-15 10:00:00
# 43   2021-07-15 11:00:00
# 44   2021-07-15 12:00:00
# 45   2021-07-15 13:00:00
# 46   2021-07-15 14:00:00
# 47   2021-07-15 15:00:00
# Name: 0, dtype: datetime64[ns]

# %% [markdown]
# ## 1.4 Process DataFrames

# %%
print(owm_fc_hr_df.info())
print(owm_fc_hr_df.describe().T)
owm_fc_hr_df = owm_fc_hr_df[["dt", "temp", "feels_like", "clouds", "wind_speed", "rain.1h"]]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dt          48 non-null     int64
#  1   temp        48 non-null     float64
#  2   feels_like  48 non-null     float64
#  3   pressure    48 non-null     int64
#  4   humidity    48 non-null     int64
#  5   dew_point   48 non-null     float64
#  6   uvi         48 non-null     float64
#  7   clouds      48 non-null     int64
#  8   visibility  48 non-null     int64
#  9   wind_speed  48 non-null     float64
#  10  wind_deg    48 non-null     int64
#  11  wind_gust   48 non-null     float64
#  12  weather     48 non-null     object
#  13  pop         48 non-null     float64
#  14  rain.1h     6 non-null      float64
#  15  lat         48 non-null     object
#  16  lon         48 non-null     object
# dtypes: float64(8), int64(6), object(3)
# memory usage: 6.5+ KB
# None
#             count          mean           std           min           25%  \
# dt           48.0  1.626269e+09  50400.000000  1.626185e+09  1.626227e+09
# temp         48.0  1.934854e+01      3.967005  1.369000e+01  1.663750e+01
# feels_like   48.0  1.936354e+01      4.099799  1.339000e+01  1.679000e+01
# pressure     48.0  1.009250e+03      2.347475  1.005000e+03  1.007000e+03
# humidity     48.0  7.681250e+01     14.411367  4.300000e+01  6.575000e+01
# dew_point    48.0  1.480979e+01      2.024862  1.150000e+01  1.331750e+01
# uvi          48.0  9.002083e-01      1.197445  0.000000e+00  0.000000e+00
# clouds       48.0  5.972917e+01     36.287704  0.000000e+00  2.300000e+01
# visibility   48.0  9.849438e+03    931.605361  3.579000e+03  1.000000e+04
# wind_speed   48.0  3.740000e+00      1.142599  2.500000e-01  2.797500e+00
# wind_deg     48.0  1.666250e+02     53.150779  4.500000e+01  1.367500e+02
# wind_gust    48.0  5.713333e+00      1.763675  1.790000e+00  4.502500e+00
# pop          48.0  1.720833e-01      0.314757  0.000000e+00  0.000000e+00
# rain.1h       6.0  2.970000e+00      2.362312  1.700000e-01  1.107500e+00
#
#                      50%           75%           max
# dt          1.626269e+09  1.626312e+09  1.626354e+09
# temp        1.928000e+01  2.126000e+01  2.947000e+01
# feels_like  1.929000e+01  2.119750e+01  2.943000e+01
# pressure    1.010000e+03  1.011000e+03  1.013000e+03
# humidity    7.950000e+01  8.825000e+01  9.700000e+01
# dew_point   1.455500e+01  1.563500e+01  1.947000e+01
# uvi         2.450000e-01  1.805000e+00  4.160000e+00
# clouds      7.000000e+01  9.300000e+01  1.000000e+02
# visibility  1.000000e+04  1.000000e+04  1.000000e+04
# wind_speed  3.850000e+00  4.360000e+00  5.700000e+00
# wind_deg    1.820000e+02  2.102500e+02  2.400000e+02
# wind_gust   5.660000e+00  6.587500e+00  9.130000e+00
# pop         1.000000e-02  1.600000e-01  1.000000e+00
# rain.1h     2.965000e+00  4.882500e+00  5.710000e+00

# %%
print(wapi_fc_hr_df.info())
print(wapi_fc_hr_df.describe().T)
wapi_fc_hr_df = wapi_fc_hr_df[["time_epoch", "time", "date", "temp_c", "wind_kph", 
                               "precip_mm", "feelslike_c", "will_it_rain", "chance_of_rain"]]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 36 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   time_epoch      72 non-null     int64
#  1   time            72 non-null     object
#  2   temp_c          72 non-null     float64
#  3   temp_f          72 non-null     float64
#  4   is_day          72 non-null     int64
#  5   wind_mph        72 non-null     float64
#  6   wind_kph        72 non-null     float64
#  7   wind_degree     72 non-null     int64
#  8   wind_dir        72 non-null     object
#  9   pressure_mb     72 non-null     float64
#  10  pressure_in     72 non-null     float64
#  11  precip_mm       72 non-null     float64
#  12  precip_in       72 non-null     float64
#  13  humidity        72 non-null     int64
#  14  cloud           72 non-null     int64
#  15  feelslike_c     72 non-null     float64
#  16  feelslike_f     72 non-null     float64
#  17  windchill_c     72 non-null     float64
#  18  windchill_f     72 non-null     float64
#  19  heatindex_c     72 non-null     float64
#  20  heatindex_f     72 non-null     float64
#  21  dewpoint_c      72 non-null     float64
#  22  dewpoint_f      72 non-null     float64
#  23  will_it_rain    72 non-null     int64
#  24  chance_of_rain  72 non-null     object
#  25  will_it_snow    72 non-null     int64
#  26  chance_of_snow  72 non-null     object
#  27  vis_km          72 non-null     float64
#  28  vis_miles       72 non-null     float64
#  29  gust_mph        72 non-null     float64
#  30  gust_kph        72 non-null     float64
#  31  uv              72 non-null     float64
#  32  condition.text  72 non-null     object
#  33  condition.icon  72 non-null     object
#  34  condition.code  72 non-null     int64
#  35  date            72 non-null     object
# dtypes: float64(21), int64(8), object(7)
# memory usage: 20.4+ KB
# None
#                 count          mean           std           min           25%  \
# time_epoch       72.0  1.626255e+09  75342.418331  1.626127e+09  1.626191e+09
# temp_c           72.0  2.000000e+01      3.562836  1.350000e+01  1.747500e+01
# temp_f           72.0  6.799444e+01      6.411431  5.630000e+01  6.345000e+01
# is_day           72.0  6.666667e-01      0.474713  0.000000e+00  0.000000e+00
# wind_mph         72.0  7.244444e+00      2.366663  3.800000e+00  5.600000e+00
# wind_kph         72.0  1.166944e+01      3.806800  6.100000e+00  9.000000e+00
# wind_degree      72.0  1.681667e+02     64.451532  4.700000e+01  9.175000e+01
# pressure_mb      72.0  1.010278e+03      2.380805  1.007000e+03  1.008000e+03
# pressure_in      72.0  3.030833e+01      0.085168  3.020000e+01  3.020000e+01
# precip_mm        72.0  5.458333e-01      1.264459  0.000000e+00  0.000000e+00
# precip_in        72.0  2.125000e-02      0.049984  0.000000e+00  0.000000e+00
# humidity         72.0  7.538889e+01     13.039005  5.300000e+01  6.600000e+01
# cloud            72.0  4.261111e+01     31.778084  1.000000e+01  1.500000e+01
# feelslike_c      72.0  2.038472e+01      4.167772  1.270000e+01  1.747500e+01
# feelslike_f      72.0  6.869028e+01      7.497176  5.490000e+01  6.345000e+01
# windchill_c      72.0  1.995000e+01      3.647225  1.270000e+01  1.747500e+01
# windchill_f      72.0  6.790694e+01      6.558949  5.490000e+01  6.345000e+01
# heatindex_c      72.0  2.080833e+01      4.221166  1.350000e+01  1.747500e+01
# heatindex_f      72.0  6.945000e+01      7.596738  5.630000e+01  6.345000e+01
# dewpoint_c       72.0  1.520972e+01      1.862919  1.160000e+01  1.360000e+01
# dewpoint_f       72.0  5.937639e+01      3.349059  5.290000e+01  5.650000e+01
# will_it_rain     72.0  1.527778e-01      0.362298  0.000000e+00  0.000000e+00
# will_it_snow     72.0  0.000000e+00      0.000000  0.000000e+00  0.000000e+00
# vis_km           72.0  9.750000e+00      0.686900  7.000000e+00  1.000000e+01
# vis_miles        72.0  5.777778e+00      0.586761  4.000000e+00  6.000000e+00
# gust_mph         72.0  1.117917e+01      2.730059  5.600000e+00  8.500000e+00
# gust_kph         72.0  1.798611e+01      4.393571  9.000000e+00  1.370000e+01
# uv               72.0  4.013889e+00      2.267300  1.000000e+00  1.000000e+00
# condition.code   72.0  1.055250e+03     96.807017  1.003000e+03  1.003000e+03
#
#                          50%           75%           max
# time_epoch      1.626255e+09  1.626319e+09  1.626383e+09
# temp_c          1.950000e+01  2.240000e+01  2.790000e+01
# temp_f          6.710000e+01  7.230000e+01  8.220000e+01
# is_day          1.000000e+00  1.000000e+00  1.000000e+00
# wind_mph        6.600000e+00  8.900000e+00  1.390000e+01
# wind_kph        1.060000e+01  1.440000e+01  2.230000e+01
# wind_degree     2.010000e+02  2.182500e+02  2.440000e+02
# pressure_mb     1.010000e+03  1.013000e+03  1.015000e+03
# pressure_in     3.030000e+01  3.040000e+01  3.050000e+01
# precip_mm       0.000000e+00  1.000000e-01  5.800000e+00
# precip_in       0.000000e+00  0.000000e+00  2.300000e-01
# humidity        7.550000e+01  8.575000e+01  9.800000e+01
# cloud           2.950000e+01  6.550000e+01  1.000000e+02
# feelslike_c     1.950000e+01  2.460000e+01  2.890000e+01
# feelslike_f     6.710000e+01  7.630000e+01  8.400000e+01
# windchill_c     1.950000e+01  2.240000e+01  2.790000e+01
# windchill_f     6.710000e+01  7.230000e+01  8.220000e+01
# heatindex_c     1.995000e+01  2.460000e+01  2.890000e+01
# heatindex_f     6.790000e+01  7.630000e+01  8.400000e+01
# dewpoint_c      1.510000e+01  1.712500e+01  1.810000e+01
# dewpoint_f      5.920000e+01  6.285000e+01  6.460000e+01
# will_it_rain    0.000000e+00  0.000000e+00  1.000000e+00
# will_it_snow    0.000000e+00  0.000000e+00  0.000000e+00
# vis_km          1.000000e+01  1.000000e+01  1.000000e+01
# vis_miles       6.000000e+00  6.000000e+00  6.000000e+00
# gust_mph        1.140000e+01  1.320000e+01  1.720000e+01
# gust_kph        1.840000e+01  2.120000e+01  2.770000e+01
# uv              5.000000e+00  6.000000e+00  7.000000e+00
# condition.code  1.003000e+03  1.020250e+03  1.243000e+03

# %%
wapi_fc_hr_df.head(5)
# Out:
#    time_epoch              time        date  temp_c  wind_kph  precip_mm  \
# 0  1626127200  2021-07-13 00:00  2021-07-13    17.7       7.9        0.0
# 1  1626130800  2021-07-13 01:00  2021-07-13    17.1       6.5        0.0
# 2  1626134400  2021-07-13 02:00  2021-07-13    16.9       6.5        0.0
# 3  1626138000  2021-07-13 03:00  2021-07-13    16.7       6.1        0.0
# 4  1626141600  2021-07-13 04:00  2021-07-13    16.5       6.1        0.0
#
#    feelslike_c  will_it_rain chance_of_rain
# 0         17.7             0              0
# 1         17.1             0              0
# 2         16.9             0              0
# 3         16.7             0              0
# 4         16.5             0              0

# %%
owm_fc_hr_df.head(5)
# Out:
#            dt   temp  feels_like  clouds  wind_speed  rain.1h
# 0  1626184800  29.47       29.42      20        4.18      NaN
# 1  1626188400  29.19       29.43      28        4.42      NaN
# 2  1626192000  28.53       29.07      40        4.31      NaN
# 3  1626195600  27.43       28.39      54        3.91      NaN
# 4  1626199200  25.08       25.39      69        3.87     0.17

# %% [markdown]
# ### 1.4 Join Data

# %%
weather_df= wapi_fc_hr_df.set_index("time_epoch").join(owm_fc_hr_df.set_index("dt"), how="outer", sort=True)

# %%
#weather_df.loc[:, weather_df["temp"].notna(), ["rain.1h"]]=weather_df[ weather_df["temp"].notna() ]["rain.1h"].fillna(0)

weather_df.loc[weather_df["temp"].notna() & weather_df["rain.1h"].isna(), "rain.1h"]=0

# %%
weather_df[ weather_df["temp"].notna() ]
# Out:
#                         time        date  temp_c  wind_kph  precip_mm  \
# 1626184800  2021-07-13 16:00  2021-07-13    27.9      14.4        0.0
# 1626188400  2021-07-13 17:00  2021-07-13    26.6      13.7        0.0
# 1626192000  2021-07-13 18:00  2021-07-13    25.3      13.0        0.0
# 1626195600  2021-07-13 19:00  2021-07-13    24.0      12.2        0.0
# 1626199200  2021-07-13 20:00  2021-07-13    23.4      11.9        0.0
# 1626202800  2021-07-13 21:00  2021-07-13    22.7      11.5        0.1
# 1626206400  2021-07-13 22:00  2021-07-13    22.1      11.2        0.1
# 1626210000  2021-07-13 23:00  2021-07-13    20.8      10.8        2.0
# 1626213600  2021-07-14 00:00  2021-07-14    19.4      10.4        3.9
# 1626217200  2021-07-14 01:00  2021-07-14    18.1      10.1        5.8
# 1626220800  2021-07-14 02:00  2021-07-14    17.9       9.0        4.7
# 1626224400  2021-07-14 03:00  2021-07-14    17.6       8.3        3.5
# 1626228000  2021-07-14 04:00  2021-07-14    17.4       7.2        2.4
# 1626231600  2021-07-14 05:00  2021-07-14    17.9       7.9        2.8
# 1626235200  2021-07-14 06:00  2021-07-14    18.3       8.3        3.2
# 1626238800  2021-07-14 07:00  2021-07-14    18.8       9.0        3.6
# 1626242400  2021-07-14 08:00  2021-07-14    18.9      11.2        2.6
# 1626246000  2021-07-14 09:00  2021-07-14    18.9      13.3        1.6
# 1626249600  2021-07-14 10:00  2021-07-14    19.0      15.5        0.6
# 1626253200  2021-07-14 11:00  2021-07-14    19.8      17.6        0.6
# 1626256800  2021-07-14 12:00  2021-07-14    20.5      20.2        0.6
# 1626260400  2021-07-14 13:00  2021-07-14    21.3      22.3        0.6
# 1626264000  2021-07-14 14:00  2021-07-14    21.5      21.2        0.4
# 1626267600  2021-07-14 15:00  2021-07-14    21.6      20.2        0.2
# 1626271200  2021-07-14 16:00  2021-07-14    21.8      19.1        0.0
# 1626274800  2021-07-14 17:00  2021-07-14    21.0      17.3        0.0
# 1626278400  2021-07-14 18:00  2021-07-14    20.1      15.5        0.0
# 1626282000  2021-07-14 19:00  2021-07-14    19.3      13.7        0.0
# 1626285600  2021-07-14 20:00  2021-07-14    18.1      12.6        0.0
# 1626289200  2021-07-14 21:00  2021-07-14    16.8      11.2        0.0
# 1626292800  2021-07-14 22:00  2021-07-14    15.6      10.1        0.0
# 1626296400  2021-07-14 23:00  2021-07-14    15.2       9.7        0.0
# 1626300000  2021-07-15 00:00  2021-07-15    14.9       9.4        0.0
# 1626303600  2021-07-15 01:00  2021-07-15    14.5       9.0        0.0
# 1626307200  2021-07-15 02:00  2021-07-15    14.2       9.7        0.0
# 1626310800  2021-07-15 03:00  2021-07-15    13.8      10.4        0.0
# 1626314400  2021-07-15 04:00  2021-07-15    13.5      11.2        0.0
# 1626318000  2021-07-15 05:00  2021-07-15    14.5      10.8        0.0
# 1626321600  2021-07-15 06:00  2021-07-15    15.5      10.4        0.0
# 1626325200  2021-07-15 07:00  2021-07-15    16.5      10.1        0.0
# 1626328800  2021-07-15 08:00  2021-07-15    17.9      10.1        0.0
# 1626332400  2021-07-15 09:00  2021-07-15    19.4      10.1        0.0
# 1626336000  2021-07-15 10:00  2021-07-15    20.8      10.1        0.0
# 1626339600  2021-07-15 11:00  2021-07-15    21.8       9.4        0.0
# 1626343200  2021-07-15 12:00  2021-07-15    22.8       8.6        0.0
# 1626346800  2021-07-15 13:00  2021-07-15    23.8       7.9        0.0
# 1626350400  2021-07-15 14:00  2021-07-15    23.7      11.2        0.0
# 1626354000  2021-07-15 15:00  2021-07-15    23.6      14.4        0.0
#
#             feelslike_c  will_it_rain chance_of_rain   temp  feels_like  \
# 1626184800         28.9             0              0  29.47       29.42
# 1626188400         27.8             0              0  29.19       29.43
# 1626192000         26.8             0              0  28.53       29.07
# 1626195600         25.7             0              0  27.43       28.39
# 1626199200         25.3             0             21  25.08       25.39
# 1626202800         25.0             0             42  22.17       22.56
# 1626206400         24.6             0             62  20.83       21.37
# 1626210000         20.8             0             66  19.84       20.41
# 1626213600         19.4             1             70  18.53       18.97
# 1626217200         18.1             1             74  17.95       18.28
# 1626220800         17.9             1             77  17.37       17.62
# 1626224400         17.6             1             79  17.40       17.65
# 1626228000         17.4             1             82  16.77       16.96
# 1626231600         17.9             1             75  16.71       16.89
# 1626235200         18.3             0             69  16.39       16.49
# 1626238800         18.8             0             62  16.42       16.47
# 1626242400         18.9             1             71  16.97       16.97
# 1626246000         18.9             1             79  17.94       17.93
# 1626249600         19.0             1             88  19.32       19.32
# 1626253200         19.8             1             80  19.58       19.53
# 1626256800         20.5             1             71  20.12       20.02
# 1626260400         21.3             0             63  20.97       20.87
# 1626264000         21.5             0             42  21.76       21.66
# 1626267600         21.6             0             21  21.24       21.14
# 1626271200         21.8             0              0  22.20       22.09
# 1626274800         21.0             0              0  22.35       22.21
# 1626278400         20.1             0              0  21.83       21.71
# 1626282000         19.3             0              0  20.65       20.65
# 1626285600         18.1             0              0  19.24       19.26
# 1626289200         16.8             0              0  17.22       17.19
# 1626292800         15.6             0              0  15.77       15.73
# 1626296400         15.1             0              0  15.08       14.97
# 1626300000         14.6             0              0  14.74       14.57
# 1626303600         14.1             0              0  14.35       14.14
# 1626307200         13.6             0              0  14.15       13.92
# 1626310800         13.2             0              0  14.07       13.80
# 1626314400         12.7             0              0  13.91       13.63
# 1626318000         14.0             0              0  13.69       13.39
# 1626321600         15.2             0              0  13.94       13.64
# 1626325200         16.5             0              0  15.57       15.35
# 1626328800         17.9             0              0  17.62       17.37
# 1626332400         19.4             0              0  19.07       18.81
# 1626336000         20.8             0              0  19.92       19.66
# 1626339600         21.8             0              0  20.46       20.23
# 1626343200         23.7             0              0  21.32       21.13
# 1626346800         25.2             0              0  21.58       21.41
# 1626350400         25.2             0              0  20.80       20.66
# 1626354000         25.1             0              0  21.22       21.12
#
#             clouds  wind_speed  rain.1h
# 1626184800    20.0        4.18     0.00
# 1626188400    28.0        4.42     0.00
# 1626192000    40.0        4.31     0.00
# 1626195600    54.0        3.91     0.00
# 1626199200    69.0        3.87     0.17
# 1626202800   100.0        2.61     1.49
# 1626206400   100.0        3.23     5.03
# 1626210000   100.0        0.25     5.71
# 1626213600   100.0        3.00     4.44
# 1626217200   100.0        3.34     0.98
# 1626220800   100.0        4.12     0.00
# 1626224400    98.0        3.54     0.00
# 1626228000    90.0        3.91     0.00
# 1626231600    93.0        4.28     0.00
# 1626235200    95.0        5.24     0.00
# 1626238800    94.0        5.46     0.00
# 1626242400    93.0        5.51     0.00
# 1626246000    81.0        5.15     0.00
# 1626249600    83.0        5.51     0.00
# 1626253200    89.0        5.07     0.00
# 1626256800    91.0        5.39     0.00
# 1626260400    88.0        5.70     0.00
# 1626264000    82.0        4.91     0.00
# 1626267600    99.0        3.83     0.00
# 1626271200    83.0        4.59     0.00
# 1626274800    73.0        4.92     0.00
# 1626278400    63.0        4.34     0.00
# 1626282000    55.0        4.13     0.00
# 1626285600    49.0        3.41     0.00
# 1626289200     0.0        2.72     0.00
# 1626292800     3.0        2.65     0.00
# 1626296400    10.0        2.80     0.00
# 1626300000     9.0        2.79     0.00
# 1626303600     8.0        2.12     0.00
# 1626307200     8.0        1.73     0.00
# 1626310800     2.0        2.25     0.00
# 1626314400     3.0        2.53     0.00
# 1626318000     5.0        2.64     0.00
# 1626321600     4.0        2.65     0.00
# 1626325200    17.0        2.39     0.00
# 1626328800    24.0        3.21     0.00
# 1626332400    39.0        3.72     0.00
# 1626336000    50.0        3.79     0.00
# 1626339600    62.0        4.12     0.00
# 1626343200    66.0        4.18     0.00
# 1626346800    71.0        4.10     0.00
# 1626350400    76.0        3.65     0.00
# 1626354000   100.0        3.35     0.00

# %% [markdown]
# ### 1.5 Calculations (groupby, merge)
#
# Here I want to simulate SQL window functions. It can be done by
# 1. `DataFrame.groupby()` (Order by in SQL)
# 2. `DataFrameGroupBy.aggregation()` (Apply any aggregation function (sum, mean etc.))
# 3. For cumulation: Return to 1. and apply `groupby(level=0).cumsum()`
# 2. `DataFrame.merge()` (Merge the aggregated values back)

# %%
day_group = weather_df.groupby("date").mean()["temp_c"]
# Out:
# Index(['2021-07-13', '2021-07-14', '2021-07-15'], dtype='object', name='date')

# %%
weather_df = weather_df.merge(day_group, 
                 left_on="date", 
                 right_index=True).rename(columns={"temp_c_y":"temp_avg_day"})

# %%
weather_df
# Out:
#                         time        date  temp_c_x  wind_kph  precip_mm  \
# 1626127200  2021-07-13 00:00  2021-07-13      17.7       7.9        0.0
# 1626130800  2021-07-13 01:00  2021-07-13      17.1       6.5        0.0
# 1626134400  2021-07-13 02:00  2021-07-13      16.9       6.5        0.0
# 1626138000  2021-07-13 03:00  2021-07-13      16.7       6.1        0.0
# 1626141600  2021-07-13 04:00  2021-07-13      16.5       6.1        0.0
# ...                      ...         ...       ...       ...        ...
# 1626368400  2021-07-15 19:00  2021-07-15      21.4       7.6        0.0
# 1626372000  2021-07-15 20:00  2021-07-15      19.9       8.3        0.0
# 1626375600  2021-07-15 21:00  2021-07-15      18.5       8.6        0.0
# 1626379200  2021-07-15 22:00  2021-07-15      17.0       9.4        0.0
# 1626382800  2021-07-15 23:00  2021-07-15      16.4       9.7        0.0
#
#             feelslike_c  will_it_rain chance_of_rain  temp  feels_like  \
# 1626127200         17.7             0              0   NaN         NaN
# 1626130800         17.1             0              0   NaN         NaN
# 1626134400         16.9             0              0   NaN         NaN
# 1626138000         16.7             0              0   NaN         NaN
# 1626141600         16.5             0              0   NaN         NaN
# ...                 ...           ...            ...   ...         ...
# 1626368400         21.4             0              0   NaN         NaN
# 1626372000         19.9             0              0   NaN         NaN
# 1626375600         18.5             0              0   NaN         NaN
# 1626379200         17.0             0              0   NaN         NaN
# 1626382800         16.4             0              0   NaN         NaN
#
#             clouds  wind_speed  rain.1h  temp_avg_day
# 1626127200     NaN         NaN      NaN     22.183333
# 1626130800     NaN         NaN      NaN     22.183333
# 1626134400     NaN         NaN      NaN     22.183333
# 1626138000     NaN         NaN      NaN     22.183333
# 1626141600     NaN         NaN      NaN     22.183333
# ...            ...         ...      ...           ...
# 1626368400     NaN         NaN      NaN     18.866667
# 1626372000     NaN         NaN      NaN     18.866667
# 1626375600     NaN         NaN      NaN     18.866667
# 1626379200     NaN         NaN      NaN     18.866667
# 1626382800     NaN         NaN      NaN     18.866667
#
# [72 rows x 14 columns]

# %%
total_rain_per_day = weather_df.groupby(["date", "time"]).sum().groupby(level=0).cumsum()["precip_mm"]
total_rain_per_day
# Out:
# date        time
# 2021-07-13  2021-07-13 00:00    0.0
#             2021-07-13 01:00    0.0
#             2021-07-13 02:00    0.0
#             2021-07-13 03:00    0.0
#             2021-07-13 04:00    0.0
#                                ...
# 2021-07-15  2021-07-15 19:00    0.0
#             2021-07-15 20:00    0.0
#             2021-07-15 21:00    0.0
#             2021-07-15 22:00    0.0
#             2021-07-15 23:00    0.0
# Name: precip_mm, Length: 72, dtype: float64

# %%
weather_df = weather_df.merge(total_rain_per_day, 
                 left_on="time", 
                 right_on="time").rename(columns={"precip_mm_y":"total_rain_per_day"})
weather_df
# Out:
#                 time        date  temp_c_x  wind_kph  precip_mm_x  \
# 0   2021-07-13 00:00  2021-07-13      17.7       7.9          0.0
# 1   2021-07-13 01:00  2021-07-13      17.1       6.5          0.0
# 2   2021-07-13 02:00  2021-07-13      16.9       6.5          0.0
# 3   2021-07-13 03:00  2021-07-13      16.7       6.1          0.0
# 4   2021-07-13 04:00  2021-07-13      16.5       6.1          0.0
# ..               ...         ...       ...       ...          ...
# 67  2021-07-15 19:00  2021-07-15      21.4       7.6          0.0
# 68  2021-07-15 20:00  2021-07-15      19.9       8.3          0.0
# 69  2021-07-15 21:00  2021-07-15      18.5       8.6          0.0
# 70  2021-07-15 22:00  2021-07-15      17.0       9.4          0.0
# 71  2021-07-15 23:00  2021-07-15      16.4       9.7          0.0
#
#     feelslike_c  will_it_rain chance_of_rain  temp  feels_like  clouds  \
# 0          17.7             0              0   NaN         NaN     NaN
# 1          17.1             0              0   NaN         NaN     NaN
# 2          16.9             0              0   NaN         NaN     NaN
# 3          16.7             0              0   NaN         NaN     NaN
# 4          16.5             0              0   NaN         NaN     NaN
# ..          ...           ...            ...   ...         ...     ...
# 67         21.4             0              0   NaN         NaN     NaN
# 68         19.9             0              0   NaN         NaN     NaN
# 69         18.5             0              0   NaN         NaN     NaN
# 70         17.0             0              0   NaN         NaN     NaN
# 71         16.4             0              0   NaN         NaN     NaN
#
#     wind_speed  rain.1h  temp_avg_day  total_rain_per_day  precip_mm
# 0          NaN      NaN     22.183333                 0.0        0.0
# 1          NaN      NaN     22.183333                 0.0        0.0
# 2          NaN      NaN     22.183333                 0.0        0.0
# 3          NaN      NaN     22.183333                 0.0        0.0
# 4          NaN      NaN     22.183333                 0.0        0.0
# ..         ...      ...           ...                 ...        ...
# 67         NaN      NaN     18.866667                 0.0        0.0
# 68         NaN      NaN     18.866667                 0.0        0.0
# 69         NaN      NaN     18.866667                 0.0        0.0
# 70         NaN      NaN     18.866667                 0.0        0.0
# 71         NaN      NaN     18.866667                 0.0        0.0
#
# [72 rows x 16 columns]
